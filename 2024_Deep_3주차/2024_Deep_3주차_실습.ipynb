# %% [markdown]
# # 학습기법 적용하기
# - MNIST를 이용한 MLP 학습

# %%
''' 1. Module Import '''
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets

# %%
''' 2. 딥러닝 모델을 설계할 때 활용하는 장비 확인 '''
print(f"MPS 장치를 지원하도록 build가 되었는가? {torch.backends.mps.is_built()}")
print(f"MPS 장치가 사용 가능한가? {torch.backends.mps.is_available()}") 
Device = torch.device("mps")
# Out:
# MPS 장치를 지원하도록 build가 되었는가? True
# MPS 장치가 사용 가능한가? True

# %%
BATCH_SIZE = 32
EPOCHS = 10

# %%
''' 3. MNIST 데이터 다운로드 (Train set, Test set 분리하기) '''
train_dataset = datasets.MNIST(root = "../data/MNIST",
                               train = True,
                               download = True,
                               transform = transforms.ToTensor())

test_dataset = datasets.MNIST(root = "../data/MNIST",
                              train = False,
                              transform = transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = BATCH_SIZE,
                                           shuffle = True)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = BATCH_SIZE,
                                          shuffle = False)

# %%
''' 4. 데이터 확인하기 (1) '''
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([32, 1, 28, 28]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %%
''' 5. 데이터 확인하기 (2) '''
pltsize = 1
plt.figure(figsize=(10 * pltsize, pltsize))
for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.axis('off')
    plt.imshow(X_train[i, :, :, :].numpy().reshape(28, 28), cmap = "gray_r")
    plt.title('Class: ' + str(y_train[i].item()))

# %% [markdown]
# ## Dropout /  Batch Normalization 적용하기

# %%
''' 6. Multi Layer Perceptron (MLP) 모델 설계하기 '''
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 512) #fully connected
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)
        
        #dropout 퍼센트 정하기
        self.dropout_prob = 0.5 #각 훈련단계에서 비활성화시킬 비율
        
        #Batch Normalization
        self.batch_norm1 = nn.BatchNorm1d(512) # 첫 번째 Layer의 Output = 512
        self.batch_norm2 = nn.BatchNorm1d(256) # 두 번째 Layer의 Output = 256

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        
        x = self.fc1(x)
        x = self.batch_norm1(x)
        x = F.relu(x) ##->초기값 설정
        
        x = F.dropout(x, training = self.training, p = self.dropout_prob) #함수 결과값에 드롭아웃 적용
        
        x = self.fc2(x)
        x = self.batch_norm2(x)
        x = F.relu(x)
        
        x = F.dropout(x, training = self.training, p = self.dropout_prob) #p=self.dropout_prob는 드롭아웃 확률
        
        x = self.fc3(x)
        x = F.log_softmax(x, dim = 1)
        return x

# %% [markdown]
# ## Initalization
# ```python
# # Xaiver Initalization
# torch.nn.init.xavier_uniform_(tensor, gain=1.0)
# torch.nn.init.xavier_normal_(tensor, gain=1.0)
#
# # He Initalization
# torch.nn.init.kaiming_uniform_(tensor, a=0, mode='fan_in', nonlinearity='leaky_relu')
# torch.nn.init.kaiming_normal_(tensor, a=0, mode='fan_in', nonlinearity='leaky_relu')
# ```
# [참고 : torch.nn.init](https://pytorch.org/docs/stable/nn.init.html)

# %% [markdown]
# ## Optimizer 설정
# ```python
# # SGD
# torch.optim.SGD(model.parameters(), lr = 0.01)
#
# # SGD (+momentum)
# torch.optim.SGD(model.parameters(), lr = 0.01, momentum = 0.5)
#
# # Adam
# torch.optim.Adam(model.parameters(), lr = 0.01)
# ```
# [참고 : torch.optim](https://pytorch.org/docs/stable/optim.html)

# %%
''' 7. Optimizer, Objective Function 설정하기 '''
# Initialization

# init 모듈 : weight, bias 등 초깃값으로 설정되는 요소에 대한 모듈
import torch.nn.init as init
def weight_init(m): # weight 초기화
    if isinstance(m, nn.Linear):
        init.kaiming_uniform_(m.weight.data) #He Initialization (앞서 ReLU 함수 적용했기 때문에)

model = Net().to(DEVICE)
model.apply(weight_init)

#Adam Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr = 0.01)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
#   (batch_norm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
''' 8. MLP 모델 학습을 진행하며 학습 데이터에 대한 모델 성능을 확인하는 함수 정의 '''
def train(model, train_loader, optimizer, log_interval):
    model.train() #모델을 학습 모드로 설정 => 활성화 
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad() #그래디언트를 0으로 초기화
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step() #가중치를 업데이트

        if batch_idx % log_interval == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}".format(
                epoch, batch_idx * len(image), #현재까지 처리된 전체 이미지의 수
                len(train_loader.dataset), 100. * batch_idx / len(train_loader), 
                loss.item()))

# %%
''' 9. 학습되는 과정 속에서 검증 데이터에 대한 모델 성능을 확인하는 함수 정의 '''
def evaluate(model, test_loader):
    model.eval() #모델을 평가 모드로 설정 => 비활성화
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item() #CrossEntropyLoss
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()
    
    test_loss /= (len(test_loader.dataset) / BATCH_SIZE)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
''' 10. MLP 학습 실행하며 Train, Test set의 Loss 및 Test set Accuracy 확인하기 '''
testloss = []
testaccuracy = []

for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.2f} % \n".format(
        epoch, test_loss, test_accuracy))
    
    testloss.append(test_loss)
    testaccuracy.append(test_accuracy)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Train Loss: 2.833838
# Train Epoch: 1 [6400/60000 (11%)]	Train Loss: 0.335014
# Train Epoch: 1 [12800/60000 (21%)]	Train Loss: 0.245715
# Train Epoch: 1 [19200/60000 (32%)]	Train Loss: 0.507998
# Train Epoch: 1 [25600/60000 (43%)]	Train Loss: 0.235739
# Train Epoch: 1 [32000/60000 (53%)]	Train Loss: 0.239120
# Train Epoch: 1 [38400/60000 (64%)]	Train Loss: 0.071790
# Train Epoch: 1 [44800/60000 (75%)]	Train Loss: 0.137265
# Train Epoch: 1 [51200/60000 (85%)]	Train Loss: 0.529212
# Train Epoch: 1 [57600/60000 (96%)]	Train Loss: 0.104362
#
# [EPOCH: 1], 	Test Loss: 0.1317, 	Test Accuracy: 95.88 %
#
# Train Epoch: 2 [0/60000 (0%)]	Train Loss: 0.764860
# Train Epoch: 2 [6400/60000 (11%)]	Train Loss: 0.129792
# Train Epoch: 2 [12800/60000 (21%)]	Train Loss: 0.388725
# Train Epoch: 2 [19200/60000 (32%)]	Train Loss: 0.305519
# Train Epoch: 2 [25600/60000 (43%)]	Train Loss: 0.226639
# Train Epoch: 2 [32000/60000 (53%)]	Train Loss: 0.450724
# Train Epoch: 2 [38400/60000 (64%)]	Train Loss: 0.207276
# Train Epoch: 2 [44800/60000 (75%)]	Train Loss: 0.399745
# Train Epoch: 2 [51200/60000 (85%)]	Train Loss: 0.181760
# Train Epoch: 2 [57600/60000 (96%)]	Train Loss: 0.077668
#
# [EPOCH: 2], 	Test Loss: 0.1009, 	Test Accuracy: 96.94 %
#
# Train Epoch: 3 [0/60000 (0%)]	Train Loss: 0.163006
# Train Epoch: 3 [6400/60000 (11%)]	Train Loss: 0.138804
# Train Epoch: 3 [12800/60000 (21%)]	Train Loss: 0.348425
# Train Epoch: 3 [19200/60000 (32%)]	Train Loss: 0.133181
# Train Epoch: 3 [25600/60000 (43%)]	Train Loss: 0.181807
# Train Epoch: 3 [32000/60000 (53%)]	Train Loss: 0.171795
# Train Epoch: 3 [38400/60000 (64%)]	Train Loss: 0.186425
# Train Epoch: 3 [44800/60000 (75%)]	Train Loss: 0.519219
# Train Epoch: 3 [51200/60000 (85%)]	Train Loss: 0.067191
# Train Epoch: 3 [57600/60000 (96%)]	Train Loss: 0.243444
#
# [EPOCH: 3], 	Test Loss: 0.0917, 	Test Accuracy: 97.19 %
#
# Train Epoch: 4 [0/60000 (0%)]	Train Loss: 0.310749
# Train Epoch: 4 [6400/60000 (11%)]	Train Loss: 0.395390
# Train Epoch: 4 [12800/60000 (21%)]	Train Loss: 0.306259
# Train Epoch: 4 [19200/60000 (32%)]	Train Loss: 0.145414
# Train Epoch: 4 [25600/60000 (43%)]	Train Loss: 0.072193
# Train Epoch: 4 [32000/60000 (53%)]	Train Loss: 0.048595
# Train Epoch: 4 [38400/60000 (64%)]	Train Loss: 0.046139
# Train Epoch: 4 [44800/60000 (75%)]	Train Loss: 0.105096
# Train Epoch: 4 [51200/60000 (85%)]	Train Loss: 0.089789
# Train Epoch: 4 [57600/60000 (96%)]	Train Loss: 0.127832
#
# [EPOCH: 4], 	Test Loss: 0.0878, 	Test Accuracy: 97.40 %
#
# Train Epoch: 5 [0/60000 (0%)]	Train Loss: 0.290434
# Train Epoch: 5 [6400/60000 (11%)]	Train Loss: 0.236670
# Train Epoch: 5 [12800/60000 (21%)]	Train Loss: 0.162691
# Train Epoch: 5 [19200/60000 (32%)]	Train Loss: 0.077744
# Train Epoch: 5 [25600/60000 (43%)]	Train Loss: 0.175316
# Train Epoch: 5 [32000/60000 (53%)]	Train Loss: 0.076400
# Train Epoch: 5 [38400/60000 (64%)]	Train Loss: 0.074512
# Train Epoch: 5 [44800/60000 (75%)]	Train Loss: 0.119548
# Train Epoch: 5 [51200/60000 (85%)]	Train Loss: 0.118484
# Train Epoch: 5 [57600/60000 (96%)]	Train Loss: 0.047095
#
# [EPOCH: 5], 	Test Loss: 0.0823, 	Test Accuracy: 97.41 %
#
# Train Epoch: 6 [0/60000 (0%)]	Train Loss: 0.095592
# Train Epoch: 6 [6400/60000 (11%)]	Train Loss: 0.172409
# Train Epoch: 6 [12800/60000 (21%)]	Train Loss: 0.140903
# Train Epoch: 6 [19200/60000 (32%)]	Train Loss: 0.214133
# Train Epoch: 6 [25600/60000 (43%)]	Train Loss: 0.636766
# Train Epoch: 6 [32000/60000 (53%)]	Train Loss: 0.101919
# Train Epoch: 6 [38400/60000 (64%)]	Train Loss: 0.324610
# Train Epoch: 6 [44800/60000 (75%)]	Train Loss: 0.100805
# Train Epoch: 6 [51200/60000 (85%)]	Train Loss: 0.175179
# Train Epoch: 6 [57600/60000 (96%)]	Train Loss: 0.099655
#
# [EPOCH: 6], 	Test Loss: 0.0783, 	Test Accuracy: 97.66 %
#
# Train Epoch: 7 [0/60000 (0%)]	Train Loss: 0.315745
# Train Epoch: 7 [6400/60000 (11%)]	Train Loss: 0.130295
# Train Epoch: 7 [12800/60000 (21%)]	Train Loss: 0.068174
# Train Epoch: 7 [19200/60000 (32%)]	Train Loss: 0.229488
# Train Epoch: 7 [25600/60000 (43%)]	Train Loss: 0.061052
# Train Epoch: 7 [32000/60000 (53%)]	Train Loss: 0.259022
# Train Epoch: 7 [38400/60000 (64%)]	Train Loss: 0.601282
# Train Epoch: 7 [44800/60000 (75%)]	Train Loss: 0.042151
# Train Epoch: 7 [51200/60000 (85%)]	Train Loss: 0.163572
# Train Epoch: 7 [57600/60000 (96%)]	Train Loss: 0.206576
#
# [EPOCH: 7], 	Test Loss: 0.0739, 	Test Accuracy: 97.68 %
#
# Train Epoch: 8 [0/60000 (0%)]	Train Loss: 0.203269
# Train Epoch: 8 [6400/60000 (11%)]	Train Loss: 0.240183
# Train Epoch: 8 [12800/60000 (21%)]	Train Loss: 0.183773
# Train Epoch: 8 [19200/60000 (32%)]	Train Loss: 0.078056
# Train Epoch: 8 [25600/60000 (43%)]	Train Loss: 0.193363
# Train Epoch: 8 [32000/60000 (53%)]	Train Loss: 0.199148
# Train Epoch: 8 [38400/60000 (64%)]	Train Loss: 0.125633
# Train Epoch: 8 [44800/60000 (75%)]	Train Loss: 0.097110
# Train Epoch: 8 [51200/60000 (85%)]	Train Loss: 0.307117
# Train Epoch: 8 [57600/60000 (96%)]	Train Loss: 0.176224
#
# [EPOCH: 8], 	Test Loss: 0.0678, 	Test Accuracy: 97.95 %
#
# Train Epoch: 9 [0/60000 (0%)]	Train Loss: 0.070168
# Train Epoch: 9 [6400/60000 (11%)]	Train Loss: 0.520178
# Train Epoch: 9 [12800/60000 (21%)]	Train Loss: 0.140279
# Train Epoch: 9 [19200/60000 (32%)]	Train Loss: 0.166223
# Train Epoch: 9 [25600/60000 (43%)]	Train Loss: 0.049978
# Train Epoch: 9 [32000/60000 (53%)]	Train Loss: 0.371805
# Train Epoch: 9 [38400/60000 (64%)]	Train Loss: 0.078019
# Train Epoch: 9 [44800/60000 (75%)]	Train Loss: 0.131102
# Train Epoch: 9 [51200/60000 (85%)]	Train Loss: 0.076487
# Train Epoch: 9 [57600/60000 (96%)]	Train Loss: 0.087749
#
# [EPOCH: 9], 	Test Loss: 0.0690, 	Test Accuracy: 97.97 %
#
# Train Epoch: 10 [0/60000 (0%)]	Train Loss: 0.144960
# Train Epoch: 10 [6400/60000 (11%)]	Train Loss: 0.415362
# Train Epoch: 10 [12800/60000 (21%)]	Train Loss: 0.082830
# Train Epoch: 10 [19200/60000 (32%)]	Train Loss: 0.021432
# Train Epoch: 10 [25600/60000 (43%)]	Train Loss: 0.085220
# Train Epoch: 10 [32000/60000 (53%)]	Train Loss: 0.048214
# Train Epoch: 10 [38400/60000 (64%)]	Train Loss: 0.054343
# Train Epoch: 10 [44800/60000 (75%)]	Train Loss: 0.043592
# Train Epoch: 10 [51200/60000 (85%)]	Train Loss: 0.020277
# Train Epoch: 10 [57600/60000 (96%)]	Train Loss: 0.071891
#
# [EPOCH: 10], 	Test Loss: 0.0712, 	Test Accuracy: 97.84 %

# %%
# 결과 시각화
plt.subplot(121)
plt.plot(testloss)
plt.title('Loss')

plt.subplot(122)
plt.plot(testaccuracy)
plt.title('Accuracy')

# 
plt.suptitle('Dropout : 0.5 / He Initialization / Adam / Batch Norm',  position = (0.5, 1.0+0.05))

plt.tight_layout()
plt.show()
