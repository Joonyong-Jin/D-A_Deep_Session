# %% [markdown]
# ## 활성화 함수
# - 활성화 함수는 신경망의 각 뉴런에서 입력신호의 가중치 합을 출력값으로 변환하는 함수(비선형)
# - 활성화 함수의 종류는 sigmoid, tanh, relu, softmax 등이 있음

# %% [markdown]
# ## 경사하강법 , 손실함수
# - 경사하강법은 초기 위치에서 함수의 기울기를 편미분을 사용해 구하고, 기울기를 활용해 함수의 최솟값으로 이동하는 과정을 반복한다.
# - 손실함수는 예측값과 실제값 사이의 오차를 나타내는 함수를 말하는데, 경사하강법은 손실함수를 최소화 시키는 목적으로 이용된다.

# %% [markdown]
# ## 딥러닝의 학습 -> 매개변수 갱신 과정
# - 먼저 입력 데이터가 순전파를 통해 가중치, 편향, 활성화 함수를 거쳐 출력됨
# - 이후에 역전파를 통해 손실함수의 기울기를 구하여 손실함수를 최소화 시키는 방향으로 매개변수를 업데이트함

# %% [markdown]
# # 학습기법 적용하기
# - MNIST를 이용한 MLP 학습

# %%
''' 1. Module Import '''
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets

# %%
''' 2. 딥러닝 모델을 설계할 때 활용하는 장비 확인 '''
print(f"MPS 장치를 지원하도록 build가 되었는가? {torch.backends.mps.is_built()}")
print(f"MPS 장치가 사용 가능한가? {torch.backends.mps.is_available()}") 
DEVICE = torch.device("mps")
# Out:
# MPS 장치를 지원하도록 build가 되었는가? True
# MPS 장치가 사용 가능한가? True

# %%
BATCH_SIZE = 32
EPOCHS = 10

# %%
''' 3. MNIST 데이터 다운로드 (Train set, Test set 분리하기) '''
train_dataset = datasets.MNIST(root = "../data/MNIST",
                               train = True,
                               download = True,
                               transform = transforms.ToTensor())

test_dataset = datasets.MNIST(root = "../data/MNIST",
                              train = False,
                              transform = transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = BATCH_SIZE,
                                           shuffle = True)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = BATCH_SIZE,
                                          shuffle = False)

# %%
''' 4. 데이터 확인하기 (1) '''
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([32, 1, 28, 28]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %%
''' 5. 데이터 확인하기 (2) '''
pltsize = 1
plt.figure(figsize=(10 * pltsize, pltsize))
for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.axis('off')
    plt.imshow(X_train[i, :, :, :].numpy().reshape(28, 28), cmap = "gray_r")
    plt.title('Class: ' + str(y_train[i].item()))

# %% [markdown]
# ## Dropout /  Batch Normalization 적용하기

# %%
''' 6. Multi Layer Perceptron (MLP) 모델 설계하기 '''
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 512) #fully connected
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)
        
        #dropout 퍼센트 정하기
        self.dropout_prob = 0.5 #각 훈련단계에서 비활성화시킬 비율
        
        #Batch Normalization
        self.batch_norm1 = nn.BatchNorm1d(512) # 첫 번째 Layer의 Output = 512
        self.batch_norm2 = nn.BatchNorm1d(256) # 두 번째 Layer의 Output = 256

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        
        x = self.fc1(x)
        x = self.batch_norm1(x)
        x = F.relu(x) ##->초기값 설정
        
        x = F.dropout(x, training = self.training, p = self.dropout_prob) #함수 결과값에 드롭아웃 적용
        
        x = self.fc2(x)
        x = self.batch_norm2(x)
        x = F.relu(x)
        
        x = F.dropout(x, training = self.training, p = self.dropout_prob) #p=self.dropout_prob는 드롭아웃 확률
        
        x = self.fc3(x)
        x = F.log_softmax(x, dim = 1)
        return x

# %% [markdown]
# ## Initalization
# ```python
# # Xaiver Initalization
# torch.nn.init.xavier_uniform_(tensor, gain=1.0)
# torch.nn.init.xavier_normal_(tensor, gain=1.0)
#
# # He Initalization
# torch.nn.init.kaiming_uniform_(tensor, a=0, mode='fan_in', nonlinearity='leaky_relu')
# torch.nn.init.kaiming_normal_(tensor, a=0, mode='fan_in', nonlinearity='leaky_relu')
# ```
# [참고 : torch.nn.init](https://pytorch.org/docs/stable/nn.init.html)

# %% [markdown]
# ## Optimizer 설정
# ```python
# # SGD
# torch.optim.SGD(model.parameters(), lr = 0.01)
#
# # SGD (+momentum)
# torch.optim.SGD(model.parameters(), lr = 0.01, momentum = 0.5)
#
# # Adam
# torch.optim.Adam(model.parameters(), lr = 0.01)
# ```
# [참고 : torch.optim](https://pytorch.org/docs/stable/optim.html)

# %%
''' 7. Optimizer, Objective Function 설정하기 '''
# Initialization

# init 모듈 : weight, bias 등 초깃값으로 설정되는 요소에 대한 모듈
import torch.nn.init as init
def weight_init(m): # weight 초기화
    if isinstance(m, nn.Linear):
        init.kaiming_uniform_(m.weight.data) #He Initialization (앞서 ReLU 함수 적용했기 때문에)

model = Net().to(DEVICE)
model.apply(weight_init)

#Adam Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr = 0.01)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
#   (batch_norm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
''' 8. MLP 모델 학습을 진행하며 학습 데이터에 대한 모델 성능을 확인하는 함수 정의 '''
def train(model, train_loader, optimizer, log_interval):
    model.train() #모델을 학습 모드로 설정 => 활성화 
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad() #그래디언트를 0으로 초기화
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step() #가중치를 업데이트

        if batch_idx % log_interval == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}".format(
                epoch, batch_idx * len(image), #현재까지 처리된 전체 이미지의 수
                len(train_loader.dataset), 100. * batch_idx / len(train_loader), 
                loss.item()))

# %%
''' 9. 학습되는 과정 속에서 검증 데이터에 대한 모델 성능을 확인하는 함수 정의 '''
def evaluate(model, test_loader):
    model.eval() #모델을 평가 모드로 설정 => 비활성화
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item() #CrossEntropyLoss
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()
    
    test_loss /= (len(test_loader.dataset) / BATCH_SIZE)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
''' 10. MLP 학습 실행하며 Train, Test set의 Loss 및 Test set Accuracy 확인하기 '''
testloss = []
testaccuracy = []

for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.2f} % \n".format(
        epoch, test_loss, test_accuracy))
    
    testloss.append(test_loss)
    testaccuracy.append(test_accuracy)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Train Loss: 3.400713
# Train Epoch: 1 [6400/60000 (11%)]	Train Loss: 0.342794
# Train Epoch: 1 [12800/60000 (21%)]	Train Loss: 0.872622
# Train Epoch: 1 [19200/60000 (32%)]	Train Loss: 0.396044
# Train Epoch: 1 [25600/60000 (43%)]	Train Loss: 0.145713
# Train Epoch: 1 [32000/60000 (53%)]	Train Loss: 0.206599
# Train Epoch: 1 [38400/60000 (64%)]	Train Loss: 0.089870
# Train Epoch: 1 [44800/60000 (75%)]	Train Loss: 0.203154
# Train Epoch: 1 [51200/60000 (85%)]	Train Loss: 0.058412
# Train Epoch: 1 [57600/60000 (96%)]	Train Loss: 0.322352
#
# [EPOCH: 1], 	Test Loss: 0.1269, 	Test Accuracy: 96.05 %
#
# Train Epoch: 2 [0/60000 (0%)]	Train Loss: 0.083321
# Train Epoch: 2 [6400/60000 (11%)]	Train Loss: 0.124954
# Train Epoch: 2 [12800/60000 (21%)]	Train Loss: 0.234727
# Train Epoch: 2 [19200/60000 (32%)]	Train Loss: 0.387490
# Train Epoch: 2 [25600/60000 (43%)]	Train Loss: 0.518184
# Train Epoch: 2 [32000/60000 (53%)]	Train Loss: 0.201657
# ...

# %%
# 결과 시각화
plt.subplot(121)
plt.plot(testloss)
plt.title('Loss')

plt.subplot(122)
plt.plot(testaccuracy)
plt.title('Accuracy')

# 
plt.suptitle('Dropout : 0.5 / He Initialization / Adam / Batch Norm',  position = (0.5, 1.0+0.05))

plt.tight_layout()
plt.show()

# %%
''' 6. Multi Layer Perceptron (MLP) 모델 설계하기 '''
# dropout 퍼센트 0.3으로 설정, 활성화 함수: ELU
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 512) #fully connected
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)
        
        #dropout 퍼센트 정하기
        self.dropout_prob = 0.3 #각 훈련단계에서 비활성화시킬 비율
        
        #Batch Normalization
        self.batch_norm1 = nn.BatchNorm1d(512) # 첫 번째 Layer의 Output = 512
        self.batch_norm2 = nn.BatchNorm1d(256) # 두 번째 Layer의 Output = 256

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        
        x = self.fc1(x)
        x = self.batch_norm1(x)
        x = F.elu(x) ##->초기값 설정
        
        x = F.dropout(x, training = self.training, p = self.dropout_prob) #함수 결과값에 드롭아웃 적용
        
        x = self.fc2(x)
        x = self.batch_norm2(x)
        x = F.elu(x)
        
        x = F.dropout(x, training = self.training, p = self.dropout_prob) #p=self.dropout_prob는 드롭아웃 확률
        
        x = self.fc3(x)
        x = F.log_softmax(x, dim = 1)
        return x

# %%
''' 7. Optimizer, Objective Function 설정하기 '''
# Initialization

# init 모듈 : weight, bias 등 초깃값으로 설정되는 요소에 대한 모듈
import torch.nn.init as init
def weight_init(m): # weight 초기화
    if isinstance(m, nn.Linear):
        init.kaiming_uniform_(m.weight.data) #He Initialization (앞서 ReLU 함수 적용했기 때문에)

model = Net().to(DEVICE)
model.apply(weight_init)

#Adam Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr = 0.01)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
#   (batch_norm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
''' 8. MLP 모델 학습을 진행하며 학습 데이터에 대한 모델 성능을 확인하는 함수 정의 '''
def train(model, train_loader, optimizer, log_interval):
    model.train() #모델을 학습 모드로 설정 => 활성화 
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad() #그래디언트를 0으로 초기화
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step() #가중치를 업데이트

        if batch_idx % log_interval == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}".format(
                epoch, batch_idx * len(image), #현재까지 처리된 전체 이미지의 수
                len(train_loader.dataset), 100. * batch_idx / len(train_loader), 
                loss.item()))

# %%
''' 9. 학습되는 과정 속에서 검증 데이터에 대한 모델 성능을 확인하는 함수 정의 '''
def evaluate(model, test_loader):
    model.eval() #모델을 평가 모드로 설정 => 비활성화
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item() #CrossEntropyLoss
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()
    
    test_loss /= (len(test_loader.dataset) / BATCH_SIZE)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
''' 10. MLP 학습 실행하며 Train, Test set의 Loss 및 Test set Accuracy 확인하기 '''
testloss = []
testaccuracy = []

for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.2f} % \n".format(
        epoch, test_loss, test_accuracy))
    
    testloss.append(test_loss)
    testaccuracy.append(test_accuracy)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Train Loss: 3.073515
# Train Epoch: 1 [6400/60000 (11%)]	Train Loss: 0.667355
# Train Epoch: 1 [12800/60000 (21%)]	Train Loss: 0.289721
# Train Epoch: 1 [19200/60000 (32%)]	Train Loss: 0.091157
# Train Epoch: 1 [25600/60000 (43%)]	Train Loss: 0.183478
# Train Epoch: 1 [32000/60000 (53%)]	Train Loss: 0.028948
# Train Epoch: 1 [38400/60000 (64%)]	Train Loss: 0.164877
# Train Epoch: 1 [44800/60000 (75%)]	Train Loss: 0.153352
# Train Epoch: 1 [51200/60000 (85%)]	Train Loss: 0.042470
# Train Epoch: 1 [57600/60000 (96%)]	Train Loss: 0.539511
#
# [EPOCH: 1], 	Test Loss: 0.1425, 	Test Accuracy: 95.71 %
#
# Train Epoch: 2 [0/60000 (0%)]	Train Loss: 0.260823
# Train Epoch: 2 [6400/60000 (11%)]	Train Loss: 0.184552
# Train Epoch: 2 [12800/60000 (21%)]	Train Loss: 0.117340
# Train Epoch: 2 [19200/60000 (32%)]	Train Loss: 0.105460
# Train Epoch: 2 [25600/60000 (43%)]	Train Loss: 0.171480
# Train Epoch: 2 [32000/60000 (53%)]	Train Loss: 0.220932
# ...

# %%
# 결과 시각화
plt.subplot(121)
plt.plot(testloss)
plt.title('Loss')

plt.subplot(122)
plt.plot(testaccuracy)
plt.title('Accuracy')

# 
plt.suptitle('Dropout : 0.3 / He Initialization / Adam / Batch Norm',  position = (0.5, 1.0+0.05))

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Drop out 0.5 -> 0.3, 활성화 함수 ELU로 변경해도 큰 차이가 나타나지 않음

# %%
''' 6. Multi Layer Perceptron (MLP) 모델 설계하기 '''
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 512) #fully connected
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)
        
        #dropout 퍼센트 정하기
        self.dropout_prob = 0.5 #각 훈련단계에서 비활성화시킬 비율
        
        #Batch Normalization
        self.batch_norm1 = nn.BatchNorm1d(512) # 첫 번째 Layer의 Output = 512
        self.batch_norm2 = nn.BatchNorm1d(256) # 두 번째 Layer의 Output = 256

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        
        x = self.fc1(x)
        x = self.batch_norm1(x)
        x = F.tanh(x) ##->초기값 설정
        
        x = F.dropout(x, training = self.training, p = self.dropout_prob) #함수 결과값에 드롭아웃 적용
        
        x = self.fc2(x)
        x = self.batch_norm2(x)
        x = F.tanh(x)
        
        x = F.dropout(x, training = self.training, p = self.dropout_prob) #p=self.dropout_prob는 드롭아웃 확률
        
        x = self.fc3(x)
        x = F.log_softmax(x, dim = 1)
        return x

# %%
''' 7. Optimizer, Objective Function 설정하기 '''
# Initialization

# init 모듈 : weight, bias 등 초깃값으로 설정되는 요소에 대한 모듈
import torch.nn.init as init
def weight_init(m): # weight 초기화
    if isinstance(m, nn.Linear):
        init.xavier_uniform_(m.weight.data) #xavier Initialization

model = Net().to(DEVICE)
model.apply(weight_init)

#Adam Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr = 0.01)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
#   (batch_norm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
''' 8. MLP 모델 학습을 진행하며 학습 데이터에 대한 모델 성능을 확인하는 함수 정의 '''
def train(model, train_loader, optimizer, log_interval):
    model.train() #모델을 학습 모드로 설정 => 활성화 
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad() #그래디언트를 0으로 초기화
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step() #가중치를 업데이트

        if batch_idx % log_interval == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}".format(
                epoch, batch_idx * len(image), #현재까지 처리된 전체 이미지의 수
                len(train_loader.dataset), 100. * batch_idx / len(train_loader), 
                loss.item()))

# %%
''' 9. 학습되는 과정 속에서 검증 데이터에 대한 모델 성능을 확인하는 함수 정의 '''
def evaluate(model, test_loader):
    model.eval() #모델을 평가 모드로 설정 => 비활성화
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item() #CrossEntropyLoss
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()
    
    test_loss /= (len(test_loader.dataset) / BATCH_SIZE)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
''' 10. MLP 학습 실행하며 Train, Test set의 Loss 및 Test set Accuracy 확인하기 '''
testloss = []
testaccuracy = []

for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.2f} % \n".format(
        epoch, test_loss, test_accuracy))
    
    testloss.append(test_loss)
    testaccuracy.append(test_accuracy)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Train Loss: 2.963282
# Train Epoch: 1 [6400/60000 (11%)]	Train Loss: 0.352952
# Train Epoch: 1 [12800/60000 (21%)]	Train Loss: 0.293309
# Train Epoch: 1 [19200/60000 (32%)]	Train Loss: 0.862372
# Train Epoch: 1 [25600/60000 (43%)]	Train Loss: 0.193530
# Train Epoch: 1 [32000/60000 (53%)]	Train Loss: 0.616999
# Train Epoch: 1 [38400/60000 (64%)]	Train Loss: 0.405075
# Train Epoch: 1 [44800/60000 (75%)]	Train Loss: 0.273536
# Train Epoch: 1 [51200/60000 (85%)]	Train Loss: 0.373804
# Train Epoch: 1 [57600/60000 (96%)]	Train Loss: 0.401302
#
# [EPOCH: 1], 	Test Loss: 0.2013, 	Test Accuracy: 93.89 %
#
# Train Epoch: 2 [0/60000 (0%)]	Train Loss: 0.569103
# Train Epoch: 2 [6400/60000 (11%)]	Train Loss: 0.378623
# Train Epoch: 2 [12800/60000 (21%)]	Train Loss: 0.245546
# Train Epoch: 2 [19200/60000 (32%)]	Train Loss: 0.279862
# Train Epoch: 2 [25600/60000 (43%)]	Train Loss: 0.414114
# Train Epoch: 2 [32000/60000 (53%)]	Train Loss: 0.383107
# ...

# %%
# 결과 시각화
plt.subplot(121)
plt.plot(testloss)
plt.title('Loss')

plt.subplot(122)
plt.plot(testaccuracy)
plt.title('Accuracy')

# 
plt.suptitle('Dropout : 0.5 / Xavier Initialization / Adam / Batch Norm',  position = (0.5, 1.0+0.05))

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 활성화 함수: tanh , 가중치 초기화 방법: Xavier Initialization, Drop out: 0.5 로 설정하니 이전보다 test accuracy가 약 0.42% 하락한 것을 볼 수 있음
